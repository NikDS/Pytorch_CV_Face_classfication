# %%
import torch 
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image
import os
import shutil
from collections import defaultdict
import numpy as np
import base64
import pandas as pd  # For Excel export

# Set up device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Load face detection model
mtcnn = MTCNN(keep_all=True, device=device)

# Load face recognition model
resnet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

# Function to detect faces in an image
def detect_faces(image_path, image_number):
    print(f"Detecting faces in Image {image_number}")
    try:
        img = Image.open(image_path)
        faces = mtcnn(img)
        if faces is not None and len(faces) > 0:
            print(f"Faces detected in Image {image_number}")
            return True
        else:
            print(f"No faces detected in Image {image_number}")
            return False
    except Exception as e:
        print(f"Error processing Image {image_number}: {str(e)}")
        return False

# Function to move images with detected faces to a new folder
def sort_images(source_folder, destination_folder):
    print(f"Sorting images from {source_folder} to {destination_folder}")
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    image_number = 1
    for filename in os.listdir(source_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(source_folder, filename)
            if detect_faces(image_path, image_number):
                shutil.move(image_path, os.path.join(destination_folder, filename))
                print(f"Moved Image {image_number} to {destination_folder}")
            image_number += 1

# Function to recognize and cluster faces based on similarity
def recognize_faces(folder_path, similarity_threshold=0.50):  # Lower threshold for fewer clusters
    print(f"Recognizing faces in {folder_path}")
    face_counts = defaultdict(int)
    known_embeddings = []
    face_images = defaultdict(list)  # Store all images for each person

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            try:
                img = Image.open(image_path)
                faces = mtcnn(img)
                
                if faces is not None:
                    faces = faces.to(device)
                    embeddings = resnet(faces).detach().cpu().numpy()
                    
                    for embedding in embeddings:
                        if not known_embeddings:
                            known_embeddings.append(embedding)
                            face_counts["Person_1"] += 1
                            face_images["Person_1"].append(image_path)  # Save image for this person
                        else:
                            # Calculate cosine similarity
                            similarities = [np.dot(embedding, known_emb) / (np.linalg.norm(embedding) * np.linalg.norm(known_emb)) for known_emb in known_embeddings]
                            max_similarity = max(similarities)
                            
                            if max_similarity > similarity_threshold:
                                cluster_id = similarities.index(max_similarity) + 1
                                face_counts[f"Person_{cluster_id}"] += 1
                                face_images[f"Person_{cluster_id}"].append(image_path)
                            else:
                                new_cluster_id = len(known_embeddings) + 1
                                known_embeddings.append(embedding)
                                face_counts[f"Person_{new_cluster_id}"] += 1
                                face_images[f"Person_{new_cluster_id}"].append(image_path)  # Save new image
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")

    return face_counts, face_images

# Function to generate an HTML file for viewing the face clusters and their associated images
def generate_html(face_counts, face_images, output_html):
    print(f"Generating HTML report in {output_html}")
    html_content = "<html><body><h1>Face Clustering Report</h1>"
    for person, count in sorted(face_counts.items(), key=lambda x: int(x[0].split('_')[1])):
        # Convert image to base64 to embed in HTML
        image_path = face_images[person][0]  # Use the first image for each person
        with open(image_path, "rb") as img_file:
            b64_string = base64.b64encode(img_file.read()).decode('utf-8')
        
        html_content += f"<h2>{person}: {count} occurrences</h2>"
        html_content += f'<img src="data:image/jpeg;base64,{b64_string}" style="width:200px;height:auto;"/><br><br>'
    
    html_content += "</body></html>"

    # Write the HTML content to the output file
    with open(output_html, "w") as file:
        file.write(html_content)

# Function to generate an Excel file with pictures tagged to each person
def generate_excel(face_counts, face_images, output_excel):
    data = []
    for person, count in sorted(face_counts.items(), key=lambda x: int(x[0].split('_')[1])):
        images = face_images[person]
        for img in images:
            # Add the person, count, and hyperlink to the image
            data.append({
                'Person': person,
                'Image Count': count,
                'Image': f'=HYPERLINK("{img}", "View Image")'
            })
    
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data)

    # Write to Excel
    df.to_excel(output_excel, index=False)
    print(f"Excel report generated at {output_excel}")

# Usage
source_folder = 'C:/Users/nrajyaguru/python files/CV Friend/Pics'
destination_folder = 'C:/Users/nrajyaguru/python files/CV Friend/Pics/test'
output_html = 'C:/Users/nrajyaguru/python files/CV Friend/Pics/report.html'
output_excel = 'C:/Users/nrajyaguru/python files/CV Friend/Pics/report.xlsx'

# Sort images into a new folder
sort_images(source_folder, destination_folder)

# Recognize faces and cluster them
face_counts, face_images = recognize_faces(destination_folder)

# Print the results
print("Unique faces and their occurrences:")
for name, count in sorted(face_counts.items(), key=lambda x: int(x[0].split('_')[1])):
    print(f"{name}: {count}")

print(f"Total unique faces: {len(face_counts)}")

# Generate an Excel report listing each person and their images
generate_excel(face_counts, face_images, output_excel)
# Out:
# Sorting images from C:/Users/nrajyaguru/python files/CV Friend/Pics to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 1
# Faces detected in Image 1
# Moved Image 1 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 2
# Faces detected in Image 2
# Moved Image 2 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 3
# Faces detected in Image 3
# Moved Image 3 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 4
# Faces detected in Image 4
# Moved Image 4 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 5
# Faces detected in Image 5
# Moved Image 5 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 6
# Faces detected in Image 6
# Moved Image 6 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 7
# Faces detected in Image 7
# Moved Image 7 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 8
# No faces detected in Image 8
# Detecting faces in Image 9
# Faces detected in Image 9
# Moved Image 9 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 10
# Faces detected in Image 10
# Moved Image 10 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 11
# No faces detected in Image 11
# Detecting faces in Image 12
# No faces detected in Image 12
# Detecting faces in Image 13
# Faces detected in Image 13
# Moved Image 13 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 14
# Faces detected in Image 14
# Moved Image 14 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 15
# No faces detected in Image 15
# Detecting faces in Image 16
# Faces detected in Image 16
# Moved Image 16 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 17
# No faces detected in Image 17
# Detecting faces in Image 18
# Faces detected in Image 18
# Moved Image 18 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 19
# No faces detected in Image 19
# Detecting faces in Image 20
# Faces detected in Image 20
# Moved Image 20 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 21
# No faces detected in Image 21
# Detecting faces in Image 22
# Faces detected in Image 22
# Moved Image 22 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 23
# Faces detected in Image 23
# Moved Image 23 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 24
# Faces detected in Image 24
# Moved Image 24 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 25
# No faces detected in Image 25
# Detecting faces in Image 26
# Faces detected in Image 26
# Moved Image 26 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 27
# Faces detected in Image 27
# Moved Image 27 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 28
# Faces detected in Image 28
# Moved Image 28 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 29
# Faces detected in Image 29
# Moved Image 29 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 30
# Faces detected in Image 30
# Moved Image 30 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 31
# Faces detected in Image 31
# Moved Image 31 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 32
# Faces detected in Image 32
# Moved Image 32 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 33
# Faces detected in Image 33
# Moved Image 33 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 34
# Faces detected in Image 34
# Moved Image 34 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 35
# Faces detected in Image 35
# Moved Image 35 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 36
# No faces detected in Image 36
# Detecting faces in Image 37
# Faces detected in Image 37
# Moved Image 37 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 38
# Faces detected in Image 38
# Moved Image 38 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 39
# Faces detected in Image 39
# Moved Image 39 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 40
# Faces detected in Image 40
# Moved Image 40 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 41
# Faces detected in Image 41
# Moved Image 41 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 42
# No faces detected in Image 42
# Detecting faces in Image 43
# Faces detected in Image 43
# Moved Image 43 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 44
# Faces detected in Image 44
# Moved Image 44 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 45
# Faces detected in Image 45
# Moved Image 45 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 46
# Faces detected in Image 46
# Moved Image 46 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 47
# Faces detected in Image 47
# Moved Image 47 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 48
# Faces detected in Image 48
# Moved Image 48 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 49
# Faces detected in Image 49
# Moved Image 49 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 50
# Faces detected in Image 50
# Moved Image 50 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 51
# Faces detected in Image 51
# Moved Image 51 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 52
# Faces detected in Image 52
# Moved Image 52 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 53
# Faces detected in Image 53
# Moved Image 53 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 54
# Faces detected in Image 54
# Moved Image 54 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 55
# Faces detected in Image 55
# Moved Image 55 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 56
# Faces detected in Image 56
# Moved Image 56 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 57
# Faces detected in Image 57
# Moved Image 57 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 58
# No faces detected in Image 58
# Detecting faces in Image 59
# Faces detected in Image 59
# Moved Image 59 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 60
# Faces detected in Image 60
# Moved Image 60 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 61
# Faces detected in Image 61
# Moved Image 61 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 62
# Faces detected in Image 62
# Moved Image 62 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 63
# Faces detected in Image 63
# Moved Image 63 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 64
# Faces detected in Image 64
# Moved Image 64 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 65
# No faces detected in Image 65
# Detecting faces in Image 66
# Faces detected in Image 66
# Moved Image 66 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 67
# Faces detected in Image 67
# Moved Image 67 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 68
# Faces detected in Image 68
# Moved Image 68 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 69
# No faces detected in Image 69
# Detecting faces in Image 70
# Faces detected in Image 70
# Moved Image 70 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 71
# Faces detected in Image 71
# Moved Image 71 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 72
# Faces detected in Image 72
# Moved Image 72 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 73
# No faces detected in Image 73
# Detecting faces in Image 74
# Faces detected in Image 74
# Moved Image 74 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 75
# No faces detected in Image 75
# Detecting faces in Image 76
# No faces detected in Image 76
# Detecting faces in Image 77
# No faces detected in Image 77
# Detecting faces in Image 78
# Faces detected in Image 78
# Moved Image 78 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 79
# Faces detected in Image 79
# Moved Image 79 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 80
# Faces detected in Image 80
# Moved Image 80 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 81
# Faces detected in Image 81
# Moved Image 81 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 82
# No faces detected in Image 82
# Detecting faces in Image 83
# Faces detected in Image 83
# Moved Image 83 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 84
# Faces detected in Image 84
# Moved Image 84 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 85
# Faces detected in Image 85
# Moved Image 85 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 86
# Faces detected in Image 86
# Moved Image 86 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 87
# Faces detected in Image 87
# Moved Image 87 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 88
# Faces detected in Image 88
# Moved Image 88 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 89
# Faces detected in Image 89
# Moved Image 89 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 90
# Faces detected in Image 90
# Moved Image 90 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 91
# Faces detected in Image 91
# Moved Image 91 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 92
# Faces detected in Image 92
# Moved Image 92 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 93
# Faces detected in Image 93
# Moved Image 93 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 94
# Faces detected in Image 94
# Moved Image 94 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 95
# Faces detected in Image 95
# Moved Image 95 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 96
# Faces detected in Image 96
# Moved Image 96 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 97
# Faces detected in Image 97
# Moved Image 97 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 98
# Faces detected in Image 98
# Moved Image 98 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 99
# Faces detected in Image 99
# Moved Image 99 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 100
# Faces detected in Image 100
# Moved Image 100 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 101
# Faces detected in Image 101
# Moved Image 101 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 102
# Faces detected in Image 102
# Moved Image 102 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 103
# Faces detected in Image 103
# Moved Image 103 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 104
# Faces detected in Image 104
# Moved Image 104 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 105
# Faces detected in Image 105
# Moved Image 105 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 106
# Faces detected in Image 106
# Moved Image 106 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 107
# Faces detected in Image 107
# Moved Image 107 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 108
# Faces detected in Image 108
# Moved Image 108 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 109
# Faces detected in Image 109
# Moved Image 109 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 110
# Faces detected in Image 110
# Moved Image 110 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 111
# Faces detected in Image 111
# Moved Image 111 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 112
# Faces detected in Image 112
# Moved Image 112 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 113
# Faces detected in Image 113
# Moved Image 113 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 114
# Faces detected in Image 114
# Moved Image 114 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 115
# Faces detected in Image 115
# Moved Image 115 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 116
# Faces detected in Image 116
# Moved Image 116 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 117
# Faces detected in Image 117
# Moved Image 117 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 118
# Faces detected in Image 118
# Moved Image 118 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 119
# Faces detected in Image 119
# Moved Image 119 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 120
# Faces detected in Image 120
# Moved Image 120 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 121
# Faces detected in Image 121
# Moved Image 121 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 122
# Faces detected in Image 122
# Moved Image 122 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 123
# Faces detected in Image 123
# Moved Image 123 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 124
# Faces detected in Image 124
# Moved Image 124 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 125
# Faces detected in Image 125
# Moved Image 125 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 126
# Faces detected in Image 126
# Moved Image 126 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 127
# Faces detected in Image 127
# Moved Image 127 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 128
# Faces detected in Image 128
# Moved Image 128 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 129
# Faces detected in Image 129
# Moved Image 129 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 130
# Faces detected in Image 130
# Moved Image 130 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 131
# Faces detected in Image 131
# Moved Image 131 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 132
# Faces detected in Image 132
# Moved Image 132 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 133
# Faces detected in Image 133
# Moved Image 133 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 134
# Faces detected in Image 134
# Moved Image 134 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 135
# Faces detected in Image 135
# Moved Image 135 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 136
# Faces detected in Image 136
# Moved Image 136 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 137
# No faces detected in Image 137
# Detecting faces in Image 138
# Faces detected in Image 138
# Moved Image 138 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 139
# Faces detected in Image 139
# Moved Image 139 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 140
# Faces detected in Image 140
# Moved Image 140 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 141
# Faces detected in Image 141
# Moved Image 141 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 142
# Faces detected in Image 142
# Moved Image 142 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 143
# Faces detected in Image 143
# Moved Image 143 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 144
# Faces detected in Image 144
# Moved Image 144 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 145
# Faces detected in Image 145
# Moved Image 145 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 146
# Faces detected in Image 146
# Moved Image 146 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 147
# Faces detected in Image 147
# Moved Image 147 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 148
# Faces detected in Image 148
# Moved Image 148 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 149
# Faces detected in Image 149
# Moved Image 149 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 150
# Faces detected in Image 150
# Moved Image 150 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 151
# Faces detected in Image 151
# Moved Image 151 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 152
# Faces detected in Image 152
# Moved Image 152 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 153
# Faces detected in Image 153
# Moved Image 153 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 154
# Faces detected in Image 154
# Moved Image 154 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 155
# Faces detected in Image 155
# Moved Image 155 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 156
# Faces detected in Image 156
# Moved Image 156 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 157
# Faces detected in Image 157
# Moved Image 157 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 158
# Faces detected in Image 158
# Moved Image 158 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 159
# Faces detected in Image 159
# Moved Image 159 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 160
# Faces detected in Image 160
# Moved Image 160 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 161
# Faces detected in Image 161
# Moved Image 161 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 162
# Faces detected in Image 162
# Moved Image 162 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 163
# Faces detected in Image 163
# Moved Image 163 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 164
# Faces detected in Image 164
# Moved Image 164 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 165
# Faces detected in Image 165
# Moved Image 165 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 166
# Faces detected in Image 166
# Moved Image 166 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 167
# Faces detected in Image 167
# Moved Image 167 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 168
# Faces detected in Image 168
# Moved Image 168 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 169
# Faces detected in Image 169
# Moved Image 169 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 170
# Faces detected in Image 170
# Moved Image 170 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 171
# Faces detected in Image 171
# Moved Image 171 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 172
# Faces detected in Image 172
# Moved Image 172 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 173
# Faces detected in Image 173
# Moved Image 173 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 174
# Faces detected in Image 174
# Moved Image 174 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 175
# Faces detected in Image 175
# Moved Image 175 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 176
# Faces detected in Image 176
# Moved Image 176 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 177
# Faces detected in Image 177
# Moved Image 177 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 178
# Faces detected in Image 178
# Moved Image 178 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 179
# Faces detected in Image 179
# Moved Image 179 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 180
# Faces detected in Image 180
# Moved Image 180 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 181
# Faces detected in Image 181
# Moved Image 181 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 182
# Faces detected in Image 182
# Moved Image 182 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 183
# Faces detected in Image 183
# Moved Image 183 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 184
# Faces detected in Image 184
# Moved Image 184 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 185
# Faces detected in Image 185
# Moved Image 185 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 186
# Faces detected in Image 186
# Moved Image 186 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 187
# Faces detected in Image 187
# Moved Image 187 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 188
# Faces detected in Image 188
# Moved Image 188 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 189
# Faces detected in Image 189
# Moved Image 189 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 190
# Faces detected in Image 190
# Moved Image 190 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 191
# Faces detected in Image 191
# Moved Image 191 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 192
# Faces detected in Image 192
# Moved Image 192 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 193
# Faces detected in Image 193
# Moved Image 193 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 194
# Faces detected in Image 194
# Moved Image 194 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 195
# Faces detected in Image 195
# Moved Image 195 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 196
# Faces detected in Image 196
# Moved Image 196 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 197
# Faces detected in Image 197
# Moved Image 197 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 198
# Faces detected in Image 198
# Moved Image 198 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 199
# Faces detected in Image 199
# Moved Image 199 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 200
# Faces detected in Image 200
# Moved Image 200 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 201
# Faces detected in Image 201
# Moved Image 201 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 202
# Faces detected in Image 202
# Moved Image 202 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 203
# Faces detected in Image 203
# Moved Image 203 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 204
# Faces detected in Image 204
# Moved Image 204 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 205
# No faces detected in Image 205
# Detecting faces in Image 206
# Faces detected in Image 206
# Moved Image 206 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 207
# Faces detected in Image 207
# Moved Image 207 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 208
# Faces detected in Image 208
# Moved Image 208 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 209
# No faces detected in Image 209
# Detecting faces in Image 210
# Faces detected in Image 210
# Moved Image 210 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 211
# Faces detected in Image 211
# Moved Image 211 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 212
# Faces detected in Image 212
# Moved Image 212 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 213
# Faces detected in Image 213
# Moved Image 213 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 214
# Faces detected in Image 214
# Moved Image 214 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 215
# Faces detected in Image 215
# Moved Image 215 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 216
# Faces detected in Image 216
# Moved Image 216 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 217
# Faces detected in Image 217
# Moved Image 217 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 218
# Faces detected in Image 218
# Moved Image 218 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 219
# Faces detected in Image 219
# Moved Image 219 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 220
# Faces detected in Image 220
# Moved Image 220 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 221
# Faces detected in Image 221
# Moved Image 221 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 222
# Faces detected in Image 222
# Moved Image 222 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 223
# Faces detected in Image 223
# Moved Image 223 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 224
# Faces detected in Image 224
# Moved Image 224 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 225
# No faces detected in Image 225
# Detecting faces in Image 226
# No faces detected in Image 226
# Detecting faces in Image 227
# Faces detected in Image 227
# Moved Image 227 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 228
# Faces detected in Image 228
# Moved Image 228 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 229
# No faces detected in Image 229
# Detecting faces in Image 230
# Faces detected in Image 230
# Moved Image 230 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 231
# No faces detected in Image 231
# Detecting faces in Image 232
# No faces detected in Image 232
# Detecting faces in Image 233
# Faces detected in Image 233
# Moved Image 233 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 234
# Faces detected in Image 234
# Moved Image 234 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 235
# Faces detected in Image 235
# Moved Image 235 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 236
# Faces detected in Image 236
# Moved Image 236 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 237
# Faces detected in Image 237
# Moved Image 237 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 238
# No faces detected in Image 238
# Detecting faces in Image 239
# Faces detected in Image 239
# Moved Image 239 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 240
# Faces detected in Image 240
# Moved Image 240 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 241
# Faces detected in Image 241
# Moved Image 241 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 242
# Faces detected in Image 242
# Moved Image 242 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 243
# Faces detected in Image 243
# Moved Image 243 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 244
# Faces detected in Image 244
# Moved Image 244 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 245
# Faces detected in Image 245
# Moved Image 245 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 246
# Faces detected in Image 246
# Moved Image 246 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 247
# Faces detected in Image 247
# Moved Image 247 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 248
# Faces detected in Image 248
# Moved Image 248 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 249
# Faces detected in Image 249
# Moved Image 249 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 250
# Faces detected in Image 250
# Moved Image 250 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 251
# Faces detected in Image 251
# Moved Image 251 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 252
# Faces detected in Image 252
# Moved Image 252 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 253
# Faces detected in Image 253
# Moved Image 253 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 254
# Faces detected in Image 254
# Moved Image 254 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 255
# Faces detected in Image 255
# Moved Image 255 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 256
# Faces detected in Image 256
# Moved Image 256 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 257
# Faces detected in Image 257
# Moved Image 257 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 258
# Faces detected in Image 258
# Moved Image 258 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 259
# Faces detected in Image 259
# Moved Image 259 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 260
# Faces detected in Image 260
# Moved Image 260 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 261
# Faces detected in Image 261
# Moved Image 261 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 262
# Faces detected in Image 262
# Moved Image 262 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 263
# Faces detected in Image 263
# Moved Image 263 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 264
# Faces detected in Image 264
# Moved Image 264 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 265
# Faces detected in Image 265
# Moved Image 265 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 266
# Faces detected in Image 266
# Moved Image 266 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 267
# Faces detected in Image 267
# Moved Image 267 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 268
# Faces detected in Image 268
# Moved Image 268 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 269
# Faces detected in Image 269
# Moved Image 269 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 270
# Faces detected in Image 270
# Moved Image 270 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 271
# Faces detected in Image 271
# Moved Image 271 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 272
# Faces detected in Image 272
# Moved Image 272 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 273
# Faces detected in Image 273
# Moved Image 273 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 274
# Faces detected in Image 274
# Moved Image 274 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 275
# Faces detected in Image 275
# Moved Image 275 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 276
# Faces detected in Image 276
# Moved Image 276 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 277
# No faces detected in Image 277
# Detecting faces in Image 278
# Faces detected in Image 278
# Moved Image 278 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 279
# No faces detected in Image 279
# Detecting faces in Image 280
# Faces detected in Image 280
# Moved Image 280 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 281
# Faces detected in Image 281
# Moved Image 281 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 282
# Faces detected in Image 282
# Moved Image 282 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 283
# Faces detected in Image 283
# Moved Image 283 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 284
# Faces detected in Image 284
# Moved Image 284 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 285
# Faces detected in Image 285
# Moved Image 285 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 286
# Faces detected in Image 286
# Moved Image 286 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 287
# Faces detected in Image 287
# Moved Image 287 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 288
# Faces detected in Image 288
# Moved Image 288 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 289
# No faces detected in Image 289
# Detecting faces in Image 290
# No faces detected in Image 290
# Detecting faces in Image 291
# No faces detected in Image 291
# Detecting faces in Image 292
# No faces detected in Image 292
# Detecting faces in Image 293
# No faces detected in Image 293
# Detecting faces in Image 294
# Faces detected in Image 294
# Moved Image 294 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 295
# Faces detected in Image 295
# Moved Image 295 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 296
# Faces detected in Image 296
# Moved Image 296 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 297
# Faces detected in Image 297
# Moved Image 297 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 298
# Faces detected in Image 298
# Moved Image 298 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 299
# Faces detected in Image 299
# Moved Image 299 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 300
# Faces detected in Image 300
# Moved Image 300 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 301
# Faces detected in Image 301
# Moved Image 301 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 302
# Faces detected in Image 302
# Moved Image 302 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 303
# Faces detected in Image 303
# Moved Image 303 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 304
# Faces detected in Image 304
# Moved Image 304 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 305
# No faces detected in Image 305
# Detecting faces in Image 306
# Faces detected in Image 306
# Moved Image 306 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 307
# No faces detected in Image 307
# Detecting faces in Image 308
# Faces detected in Image 308
# Moved Image 308 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 309
# Faces detected in Image 309
# Moved Image 309 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 310
# No faces detected in Image 310
# Detecting faces in Image 311
# No faces detected in Image 311
# Detecting faces in Image 312
# Faces detected in Image 312
# Moved Image 312 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 313
# Faces detected in Image 313
# Moved Image 313 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 314
# Faces detected in Image 314
# Moved Image 314 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 315
# Faces detected in Image 315
# Moved Image 315 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 316
# Faces detected in Image 316
# Moved Image 316 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 317
# Faces detected in Image 317
# Moved Image 317 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 318
# Faces detected in Image 318
# Moved Image 318 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 319
# Faces detected in Image 319
# Moved Image 319 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 320
# Faces detected in Image 320
# Moved Image 320 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 321
# Faces detected in Image 321
# Moved Image 321 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 322
# Faces detected in Image 322
# Moved Image 322 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 323
# Faces detected in Image 323
# Moved Image 323 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 324
# Faces detected in Image 324
# Moved Image 324 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 325
# Faces detected in Image 325
# Moved Image 325 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 326
# Faces detected in Image 326
# Moved Image 326 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 327
# Faces detected in Image 327
# Moved Image 327 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 328
# Faces detected in Image 328
# Moved Image 328 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 329
# Faces detected in Image 329
# Moved Image 329 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 330
# Faces detected in Image 330
# Moved Image 330 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 331
# Faces detected in Image 331
# Moved Image 331 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 332
# Faces detected in Image 332
# Moved Image 332 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 333
# Faces detected in Image 333
# Moved Image 333 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 334
# Faces detected in Image 334
# Moved Image 334 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 335
# Faces detected in Image 335
# Moved Image 335 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 336
# Faces detected in Image 336
# Moved Image 336 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 337
# Faces detected in Image 337
# Moved Image 337 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 338
# Faces detected in Image 338
# Moved Image 338 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 339
# Faces detected in Image 339
# Moved Image 339 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 340
# Faces detected in Image 340
# Moved Image 340 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 341
# Faces detected in Image 341
# Moved Image 341 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 342
# Faces detected in Image 342
# Moved Image 342 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 343
# Faces detected in Image 343
# Moved Image 343 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 344
# Faces detected in Image 344
# Moved Image 344 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 345
# Faces detected in Image 345
# Moved Image 345 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 346
# Faces detected in Image 346
# Moved Image 346 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 347
# Faces detected in Image 347
# Moved Image 347 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 348
# No faces detected in Image 348
# Detecting faces in Image 349
# Faces detected in Image 349
# Moved Image 349 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 350
# No faces detected in Image 350
# Detecting faces in Image 351
# Faces detected in Image 351
# Moved Image 351 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 352
# Faces detected in Image 352
# Moved Image 352 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 353
# Faces detected in Image 353
# Moved Image 353 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 354
# Faces detected in Image 354
# Moved Image 354 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 355
# Faces detected in Image 355
# Moved Image 355 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 356
# Faces detected in Image 356
# Moved Image 356 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 357
# Faces detected in Image 357
# Moved Image 357 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 358
# Faces detected in Image 358
# Moved Image 358 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 359
# Faces detected in Image 359
# Moved Image 359 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 360
# Faces detected in Image 360
# Moved Image 360 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 361
# Faces detected in Image 361
# Moved Image 361 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 362
# Faces detected in Image 362
# Moved Image 362 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 363
# Faces detected in Image 363
# Moved Image 363 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 364
# Faces detected in Image 364
# Moved Image 364 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 365
# Faces detected in Image 365
# Moved Image 365 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 366
# Faces detected in Image 366
# Moved Image 366 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 367
# Faces detected in Image 367
# Moved Image 367 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 368
# Faces detected in Image 368
# Moved Image 368 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 369
# Faces detected in Image 369
# Moved Image 369 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 370
# Faces detected in Image 370
# Moved Image 370 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 371
# Faces detected in Image 371
# Moved Image 371 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 372
# Faces detected in Image 372
# Moved Image 372 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 373
# Faces detected in Image 373
# Moved Image 373 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 374
# Faces detected in Image 374
# Moved Image 374 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 375
# Faces detected in Image 375
# Moved Image 375 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 376
# Faces detected in Image 376
# Moved Image 376 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 377
# No faces detected in Image 377
# Detecting faces in Image 378
# Faces detected in Image 378
# Moved Image 378 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 379
# Faces detected in Image 379
# Moved Image 379 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 380
# Faces detected in Image 380
# Moved Image 380 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 381
# Faces detected in Image 381
# Moved Image 381 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 382
# Faces detected in Image 382
# Moved Image 382 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 383
# Faces detected in Image 383
# Moved Image 383 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 384
# Faces detected in Image 384
# Moved Image 384 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 385
# Faces detected in Image 385
# Moved Image 385 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 386
# Faces detected in Image 386
# Moved Image 386 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 387
# Faces detected in Image 387
# Moved Image 387 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 388
# No faces detected in Image 388
# Detecting faces in Image 389
# Faces detected in Image 389
# Moved Image 389 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 390
# Faces detected in Image 390
# Moved Image 390 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 391
# Faces detected in Image 391
# Moved Image 391 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 392
# Faces detected in Image 392
# Moved Image 392 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 393
# No faces detected in Image 393
# Detecting faces in Image 394
# Faces detected in Image 394
# Moved Image 394 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 395
# Faces detected in Image 395
# Moved Image 395 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 396
# No faces detected in Image 396
# Detecting faces in Image 397
# No faces detected in Image 397
# Detecting faces in Image 398
# Faces detected in Image 398
# Moved Image 398 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 399
# Faces detected in Image 399
# Moved Image 399 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 400
# Faces detected in Image 400
# Moved Image 400 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 401
# Faces detected in Image 401
# Moved Image 401 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 402
# Faces detected in Image 402
# Moved Image 402 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 403
# Faces detected in Image 403
# Moved Image 403 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 404
# Faces detected in Image 404
# Moved Image 404 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 405
# Faces detected in Image 405
# Moved Image 405 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 406
# Faces detected in Image 406
# Moved Image 406 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 407
# Faces detected in Image 407
# Moved Image 407 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 408
# Faces detected in Image 408
# Moved Image 408 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 409
# Faces detected in Image 409
# Moved Image 409 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 410
# Faces detected in Image 410
# Moved Image 410 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 411
# Faces detected in Image 411
# Moved Image 411 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 412
# No faces detected in Image 412
# Detecting faces in Image 413
# Faces detected in Image 413
# Moved Image 413 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 414
# Faces detected in Image 414
# Moved Image 414 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 415
# Faces detected in Image 415
# Moved Image 415 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 416
# Faces detected in Image 416
# Moved Image 416 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 417
# Faces detected in Image 417
# Moved Image 417 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 418
# Faces detected in Image 418
# Moved Image 418 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 419
# No faces detected in Image 419
# Detecting faces in Image 420
# No faces detected in Image 420
# Detecting faces in Image 421
# No faces detected in Image 421
# Detecting faces in Image 422
# No faces detected in Image 422
# Detecting faces in Image 423
# Faces detected in Image 423
# Moved Image 423 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 424
# No faces detected in Image 424
# Detecting faces in Image 425
# No faces detected in Image 425
# Detecting faces in Image 426
# Faces detected in Image 426
# Moved Image 426 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 427
# No faces detected in Image 427
# Detecting faces in Image 428
# Faces detected in Image 428
# Moved Image 428 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 429
# Faces detected in Image 429
# Moved Image 429 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 430
# No faces detected in Image 430
# Detecting faces in Image 431
# Faces detected in Image 431
# Moved Image 431 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 432
# No faces detected in Image 432
# Detecting faces in Image 433
# Faces detected in Image 433
# Moved Image 433 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 434
# No faces detected in Image 434
# Detecting faces in Image 435
# No faces detected in Image 435
# Detecting faces in Image 436
# Faces detected in Image 436
# Moved Image 436 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 437
# Faces detected in Image 437
# Moved Image 437 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 438
# Faces detected in Image 438
# Moved Image 438 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 439
# Faces detected in Image 439
# Moved Image 439 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 440
# Faces detected in Image 440
# Moved Image 440 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 441
# No faces detected in Image 441
# Detecting faces in Image 442
# Faces detected in Image 442
# Moved Image 442 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 443
# Faces detected in Image 443
# Moved Image 443 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 444
# Faces detected in Image 444
# Moved Image 444 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 445
# No faces detected in Image 445
# Detecting faces in Image 446
# Faces detected in Image 446
# Moved Image 446 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 447
# Faces detected in Image 447
# Moved Image 447 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 448
# Faces detected in Image 448
# Moved Image 448 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 449
# Faces detected in Image 449
# Moved Image 449 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 450
# No faces detected in Image 450
# Detecting faces in Image 451
# No faces detected in Image 451
# Detecting faces in Image 452
# No faces detected in Image 452
# Detecting faces in Image 453
# Faces detected in Image 453
# Moved Image 453 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 454
# Faces detected in Image 454
# Moved Image 454 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 455
# No faces detected in Image 455
# Detecting faces in Image 456
# Faces detected in Image 456
# Moved Image 456 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 457
# Faces detected in Image 457
# Moved Image 457 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 458
# No faces detected in Image 458
# Detecting faces in Image 459
# Faces detected in Image 459
# Moved Image 459 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 460
# Faces detected in Image 460
# Moved Image 460 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 461
# No faces detected in Image 461
# Detecting faces in Image 462
# Faces detected in Image 462
# Moved Image 462 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 463
# Faces detected in Image 463
# Moved Image 463 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 464
# Faces detected in Image 464
# Moved Image 464 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 465
# No faces detected in Image 465
# Detecting faces in Image 466
# Faces detected in Image 466
# Moved Image 466 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 467
# No faces detected in Image 467
# Detecting faces in Image 468
# Faces detected in Image 468
# Moved Image 468 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 469
# Faces detected in Image 469
# Moved Image 469 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 470
# Faces detected in Image 470
# Moved Image 470 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Detecting faces in Image 471
# Faces detected in Image 471
# Moved Image 471 to C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Recognizing faces in C:/Users/nrajyaguru/python files/CV Friend/Pics/test
# Unique faces and their occurrences:
# Person_1: 81
# Person_2: 355
# Person_3: 72
# Person_4: 12
# Person_5: 13
# Person_6: 17
# Person_7: 16
# Person_8: 17
# Person_9: 14
# Person_10: 22
# Person_11: 100
# Person_12: 23
# Person_13: 9
# Person_14: 10
# Person_15: 12
# Person_16: 22
# Person_17: 17
# Person_18: 16
# Person_19: 11
# Person_20: 5
# Person_21: 6
# Person_22: 6
# Person_23: 1
# Person_24: 5
# Person_25: 4
# Person_26: 4
# Person_27: 8
# Person_28: 5
# Person_29: 2
# Person_30: 4
# Person_31: 28
# Person_32: 10
# Person_33: 44
# Person_34: 12
# Person_35: 2
# Person_36: 16
# Person_37: 3
# Person_38: 18
# Person_39: 5
# Person_40: 9
# Person_41: 2
# Person_42: 11
# Person_43: 17
# Person_44: 26
# Person_45: 8
# Person_46: 2
# Person_47: 20
# Person_48: 6
# Person_49: 4
# Person_50: 37
# Person_51: 1
# Person_52: 7
# Person_53: 4
# Person_54: 7
# Person_55: 5
# Person_56: 1
# Person_57: 7
# Person_58: 1
# Person_59: 2
# Person_60: 7
# Person_61: 2
# Person_62: 16
# Person_63: 6
# Person_64: 6
# Person_65: 5
# Person_66: 7
# Person_67: 11
# Person_68: 3
# Person_69: 3
# Person_70: 7
# Person_71: 2
# Person_72: 2
# Person_73: 1
# Person_74: 29
# Person_75: 13
# Person_76: 1
# Person_77: 4
# Person_78: 2
# Person_79: 18
# Person_80: 7
# Person_81: 5
# Person_82: 10
# Person_83: 11
# Person_84: 10
# Person_85: 5
# Person_86: 2
# Person_87: 2
# Person_88: 2
# Person_89: 5
# Person_90: 8
# Person_91: 3
# Person_92: 11
# Person_93: 4
# Person_94: 2
# Person_95: 6
# Person_96: 9
# Person_97: 4
# Person_98: 6
# Person_99: 1
# Person_100: 9
# Person_101: 4
# Person_102: 10
# Person_103: 3
# Person_104: 2
# Person_105: 7
# Person_106: 3
# Person_107: 1
# Person_108: 26
# Person_109: 2
# Person_110: 2
# Person_111: 8
# Person_112: 5
# Person_113: 5
# Person_114: 4
# Person_115: 8
# Person_116: 1
# Person_117: 1
# Person_118: 5
# Person_119: 2
# Person_120: 22
# Person_121: 5
# Person_122: 2
# Person_123: 8
# Person_124: 1
# Person_125: 1
# Person_126: 2
# Person_127: 1
# Person_128: 3
# Person_129: 3
# Person_130: 13
# Person_131: 11
# Person_132: 3
# Person_133: 3
# Person_134: 8
# Person_135: 3
# Person_136: 1
# Person_137: 1
# Person_138: 9
# Person_139: 13
# Person_140: 19
# Person_141: 2
# Person_142: 19
# Person_143: 2
# Person_144: 5
# Person_145: 1
# Person_146: 4
# Person_147: 5
# Person_148: 3
# Person_149: 2
# Person_150: 1
# Person_151: 2
# Person_152: 1
# Person_153: 1
# Person_154: 6
# Person_155: 8
# Person_156: 2
# Person_157: 3
# Person_158: 5
# Person_159: 3
# Person_160: 4
# Person_161: 2
# Person_162: 6
# Person_163: 3
# Person_164: 2
# Person_165: 5
# Person_166: 3
# Person_167: 2
# Person_168: 6
# Person_169: 6
# Person_170: 2
# Person_171: 1
# Person_172: 6
# Person_173: 3
# Person_174: 2
# Person_175: 1
# Person_176: 3
# Person_177: 2
# Person_178: 10
# Person_179: 1
# Person_180: 1
# Person_181: 2
# Person_182: 1
# Person_183: 5
# Person_184: 1
# Person_185: 9
# Person_186: 10
# Person_187: 1
# Person_188: 2
# Person_189: 3
# Person_190: 3
# Person_191: 3
# Person_192: 1
# Person_193: 2
# Person_194: 2
# Person_195: 4
# Person_196: 3
# Person_197: 7
# Person_198: 6
# Person_199: 1
# Person_200: 2
# Person_201: 1
# Person_202: 2
# Person_203: 1
# Person_204: 2
# Person_205: 5
# Person_206: 5
# Person_207: 1
# Person_208: 1
# Person_209: 7
# Person_210: 3
# Person_211: 2
# Person_212: 1
# Person_213: 1
# Person_214: 2
# Person_215: 5
# Person_216: 3
# Person_217: 1
# Person_218: 1
# Person_219: 1
# Person_220: 1
# Person_221: 2
# Person_222: 3
# Person_223: 2
# Person_224: 5
# Person_225: 2
# Person_226: 1
# Person_227: 9
# Person_228: 2
# Person_229: 2
# Person_230: 1
# Person_231: 1
# Person_232: 3
# Person_233: 2
# Person_234: 1
# Person_235: 5
# Person_236: 1
# Person_237: 1
# Person_238: 1
# Person_239: 1
# Person_240: 1
# Person_241: 1
# Person_242: 1
# Person_243: 1
# Person_244: 1
# Person_245: 1
# Person_246: 2
# Person_247: 1
# Person_248: 1
# Person_249: 2
# Person_250: 1
# Person_251: 1
# Person_252: 1
# Person_253: 1
# Person_254: 1
# Person_255: 1
# Person_256: 1
# Person_257: 1
# Person_258: 1
# Person_259: 1
# Person_260: 14
# Person_261: 1
# Person_262: 4
# Person_263: 1
# Person_264: 4
# Person_265: 2
# Person_266: 2
# Person_267: 3
# Person_268: 1
# Person_269: 1
# Person_270: 1
# Person_271: 1
# Person_272: 1
# Person_273: 1
# Person_274: 1
# Person_275: 1
# Person_276: 1
# Person_277: 1
# Person_278: 1
# Person_279: 1
# Person_280: 1
# Total unique faces: 280
# Excel report generated at C:/Users/nrajyaguru/python files/CV Friend/Pics/report.xlsx
# Excel report generated at C:/Users/nrajyaguru/python files/CV Friend/Pics/report.xlsx

# %%
df = pd.read_excel('C:/Users/nrajyaguru/python files/CV Friend/Pics/report.xlsx')

# %%
df.sample(10)
# Out:
#           Person  Image Count  Image
# 1439   Person_95            6    NaN
# 872    Person_27            8    NaN
# 240     Person_2          355    NaN
# 1834  Person_177            2    NaN
# 958    Person_33           44    NaN
# 1706  Person_142           19    NaN
# 446     Person_3           72    NaN
# 1132   Person_50           37    NaN
# 1619  Person_130           13    NaN
# 752    Person_14           10    NaN
